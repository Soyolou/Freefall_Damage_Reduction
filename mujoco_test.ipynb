# %%
import mujoco
import numpy as np
import mediapy as media
import matplotlib.pyplot as plt
np.set_printoptions(precision=3, suppress=True, linewidth=100)
import gym
from gym import spaces
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
import csv
from stable_baselines3.common.logger import configure

# %%
humanoid_xml = r"""<mujoco model="Humanoid">
  <option timestep="0.005"/>

  <visual>
    <map force="0.1" zfar="30"/>
    <rgba haze="0.15 0.25 0.35 1"/>
    <global offwidth="2560" offheight="1440" elevation="-20" azimuth="120"/>
  </visual>

  <statistic center="0 0 0.7"/>

  <asset>
    <texture type="skybox" builtin="gradient" rgb1=".3 .5 .7" rgb2="0 0 0" width="32" height="512"/>
    <texture name="body" type="cube" builtin="flat" mark="cross" width="127" height="1278" rgb1="0.8 0.6 0.4" rgb2="0.8 0.6 0.4" markrgb="1 1 1" random="0.01"/>
    <material name="body" texture="body" texuniform="true" rgba="0.8 0.6 .4 1"/>
    <texture name="grid" type="2d" builtin="checker" width="512" height="512" rgb1=".1 .2 .3" rgb2=".2 .3 .4"/>
    <material name="grid" texture="grid" texrepeat="1 1" texuniform="true" reflectance=".2"/>
  </asset>

  <default>
    <motor ctrlrange="-1 1" ctrllimited="true"/>
    <default class="body">

      <!-- geoms -->
      <geom type="capsule" condim="1" friction=".7" solimp=".9 .99 .003" solref=".015 1" material="body"/>
      <default class="thigh">
        <geom size=".06"/>
      </default>
      <default class="shin">
        <geom fromto="0 0 0 0 0 -.3"  size=".049"/>
      </default>
      <default class="foot">
        <geom size=".027"/>
        <default class="foot1">
          <geom fromto="-.07 -.01 0 .14 -.03 0"/>
        </default>
        <default class="foot2">
          <geom fromto="-.07 .01 0 .14  .03 0"/>
        </default>
      </default>
      <default class="arm_upper">
        <geom size=".04"/>
      </default>
      <default class="arm_lower">
        <geom size=".031"/>
      </default>
      <default class="hand">
        <geom type="sphere" size=".04"/>
      </default>

      <!-- joints -->
      <joint type="hinge" damping=".2" stiffness="1" armature=".01" limited="true" solimplimit="0 .99 .01"/>
      <default class="joint_big">
        <joint damping="5" stiffness="10"/>
        <default class="hip_x">
          <joint range="-30 10"/>
        </default>
        <default class="hip_z">
          <joint range="-60 35"/>
        </default>
        <default class="hip_y">
          <joint axis="0 1 0" range="-150 20"/>
        </default>
        <default class="joint_big_stiff">
          <joint stiffness="20"/>
        </default>
      </default>
      <default class="knee">
        <joint pos="0 0 .02" axis="0 -1 0" range="-160 2"/>
      </default>
      <default class="ankle">
        <joint range="-50 50"/>
        <default class="ankle_y">
          <joint pos="0 0 .08" axis="0 1 0" stiffness="6"/>
        </default>
        <default class="ankle_x">
          <joint pos="0 0 .04" stiffness="3"/>
        </default>
      </default>
      <default class="shoulder">
        <joint range="-85 60"/>
      </default>
      <default class="elbow">
        <joint range="-100 50" stiffness="0"/>
      </default>
    </default>
  </default>

  <worldbody>
    <geom name="floor" size="0 0 .05" type="plane" material="grid" condim="3"/>
    <light name="spotlight" mode="targetbodycom" target="torso" diffuse=".8 .8 .8" specular="0.3 0.3 0.3" pos="0 -6 4" cutoff="30"/>
    <body name="torso" pos="0 0 1.282" childclass="body">
      <light name="top" pos="0 0 2" mode="trackcom"/>
      <camera name="back" pos="-3 0 1" xyaxes="0 -1 0 1 0 2" mode="trackcom"/>
      <camera name="side" pos="0 -3 1" xyaxes="1 0 0 0 1 2" mode="trackcom"/>
      <freejoint name="root"/>
      <geom name="torso" fromto="0 -.07 0 0 .07 0" size=".07"/>
      <geom name="waist_upper" fromto="-.01 -.06 -.12 -.01 .06 -.12" size=".06"/>
      <body name="head" pos="0 0 .19">
        <geom name="head" type="sphere" size=".09"/>
        <site name="sensor"/>
        <camera name="egocentric" pos=".09 0 0" xyaxes="0 -1 0 .1 0 1" fovy="80"/>
      </body>
      <body name="waist_lower" pos="-.01 0 -.26">
        <geom name="waist_lower" fromto="0 -.06 0 0 .06 0" size=".06"/>
        <joint name="abdomen_z" pos="0 0 .065" axis="0 0 1" range="-45 45" class="joint_big_stiff"/>
        <joint name="abdomen_y" pos="0 0 .065" axis="0 1 0" range="-75 30" class="joint_big"/>
        <body name="pelvis" pos="0 0 -.165">
          <joint name="abdomen_x" pos="0 0 .1" axis="1 0 0" range="-35 35" class="joint_big"/>
          <geom name="butt" fromto="-.02 -.07 0 -.02 .07 0" size=".09"/>
          <body name="thigh_right" pos="0 -.1 -.04">
            <joint name="hip_x_right" axis="1 0 0" class="hip_x"/>
            <joint name="hip_z_right" axis="0 0 1" class="hip_z"/>
            <joint name="hip_y_right" class="hip_y"/>
            <geom name="thigh_right" fromto="0 0 0 0 .01 -.34" class="thigh"/>
            <body name="shin_right" pos="0 .01 -.4">
              <joint name="knee_right" class="knee"/>
              <geom name="shin_right" class="shin"/>
              <body name="foot_right" pos="0 0 -.39">
                <joint name="ankle_y_right" class="ankle_y"/>
                <joint name="ankle_x_right" class="ankle_x" axis="1 0 .5"/>
                <geom name="foot1_right" class="foot1"/>
                <geom name="foot2_right" class="foot2"/>
              </body>
            </body>
          </body>
          <body name="thigh_left" pos="0 .1 -.04">
            <joint name="hip_x_left" axis="-1 0 0" class="hip_x"/>
            <joint name="hip_z_left" axis="0 0 -1" class="hip_z"/>
            <joint name="hip_y_left" class="hip_y"/>
            <geom name="thigh_left" fromto="0 0 0 0 -.01 -.34" class="thigh"/>
            <body name="shin_left" pos="0 -.01 -.4">
              <joint name="knee_left" class="knee"/>
              <geom name="shin_left" fromto="0 0 0 0 0 -.3" class="shin"/>
              <body name="foot_left" pos="0 0 -.39">
                <joint name="ankle_y_left" class="ankle_y"/>
                <joint name="ankle_x_left" class="ankle_x" axis="-1 0 -.5"/>
                <geom name="foot1_left" class="foot1"/>
                <geom name="foot2_left" class="foot2"/>
              </body>
            </body>
          </body>
        </body>
      </body>
      <body name="upper_arm_right" pos="0 -.17 .06">
        <joint name="shoulder1_right" axis="2 1 1"  class="shoulder"/>
        <joint name="shoulder2_right" axis="0 -1 1" class="shoulder"/>
        <geom name="upper_arm_right" fromto="0 0 0 .16 -.16 -.16" class="arm_upper"/>
        <body name="lower_arm_right" pos=".18 -.18 -.18">
          <joint name="elbow_right" axis="0 -1 1" class="elbow"/>
          <geom name="lower_arm_right" fromto=".01 .01 .01 .17 .17 .17" class="arm_lower"/>
          <body name="hand_right" pos=".18 .18 .18">
            <geom name="hand_right" zaxis="1 1 1" class="hand"/>
          </body>
        </body>
      </body>
      <body name="upper_arm_left" pos="0 .17 .06">
        <joint name="shoulder1_left" axis="-2 1 -1" class="shoulder"/>
        <joint name="shoulder2_left" axis="0 -1 -1"  class="shoulder"/>
        <geom name="upper_arm_left" fromto="0 0 0 .16 .16 -.16" class="arm_upper"/>
        <body name="lower_arm_left" pos=".18 .18 -.18">
          <joint name="elbow_left" axis="0 -1 -1" class="elbow"/>
          <geom name="lower_arm_left" fromto=".01 -.01 .01 .17 -.17 .17" class="arm_lower"/>
          <body name="hand_left" pos=".18 -.18 .18">
            <geom name="hand_left" zaxis="1 -1 1" class="hand"/>
          </body>
        </body>
      </body>
    </body>
  </worldbody>

  
  <sensor>
    <velocimeter name="velocity" site="sensor"/>
  </sensor>

  <tendon>
    <fixed name="hamstring_right" limited="true" range="-0.3 2">
      <joint joint="hip_y_right" coef=".5"/>
      <joint joint="knee_right" coef="-.5"/>
    </fixed>
    <fixed name="hamstring_left" limited="true" range="-0.3 2">
      <joint joint="hip_y_left" coef=".5"/>
      <joint joint="knee_left" coef="-.5"/>
    </fixed>
  </tendon>

  <actuator>
    <motor name="abdomen_y"       gear="40"  joint="abdomen_y"/>
    <motor name="abdomen_z"       gear="40"  joint="abdomen_z"/>
    <motor name="abdomen_x"       gear="40"  joint="abdomen_x"/>
    <motor name="hip_x_right"     gear="40"  joint="hip_x_right"/>
    <motor name="hip_z_right"     gear="40"  joint="hip_z_right"/>
    <motor name="hip_y_right"     gear="120" joint="hip_y_right"/>
    <motor name="knee_right"      gear="80"  joint="knee_right"/>
    <motor name="ankle_x_right"   gear="20"  joint="ankle_x_right"/>
    <motor name="ankle_y_right"   gear="20"  joint="ankle_y_right"/>
    <motor name="hip_x_left"      gear="40"  joint="hip_x_left"/>
    <motor name="hip_z_left"      gear="40"  joint="hip_z_left"/>
    <motor name="hip_y_left"      gear="120" joint="hip_y_left"/>
    <motor name="knee_left"       gear="80"  joint="knee_left"/>
    <motor name="ankle_x_left"    gear="20"  joint="ankle_x_left"/>
    <motor name="ankle_y_left"    gear="20"  joint="ankle_y_left"/>
    <motor name="shoulder1_right" gear="20"  joint="shoulder1_right"/>
    <motor name="shoulder2_right" gear="20"  joint="shoulder2_right"/>
    <motor name="elbow_right"     gear="40"  joint="elbow_right"/>
    <motor name="shoulder1_left"  gear="20"  joint="shoulder1_left"/>
    <motor name="shoulder2_left"  gear="20"  joint="shoulder2_left"/>
    <motor name="elbow_left"      gear="40"  joint="elbow_left"/>
  </actuator>

  <keyframe>
    <!--
    The values below are split into rows for readibility:
      torso position
      torso orientation
      spinal
      right leg
      left leg
      arms
    -->
    <key name="squat" qpos="0 0 2
                            0 0.988015 0.154359 0
                            0 0.4 0
                            -0.25 -0.5 -2.5 -2.65 -0.8 0.56
                            -0.25 -0.5 -2.5 -2.65 -0.8 0.56
                            0 0 0 0 0 0"/>
    <key name="midmost_point_of_a_seoi_nage" qpos="0 0 1.21948
                                        0.971588 -0.179973 0.135318 -0.0729076
                                        -0.0516 -0.202 0.23
                                        -0.24 -0.007 -0.34 -1.76 -0.466 -0.0415
                                        -0.08 -0.01 -0.37 -0.685 -0.35 -0.09
                                        0.109 -0.067 -0.7 -0.05 0.12 0.16"/>
  </keyframe>
</mujoco>"""

# %%
class humanoidEnv(gym.Env):
    """Custom Environment that follows gym interface."""

    metadata = {"render.modes": ["human"]}

    def __init__(self, xml: str):
        super().__init__()
        self.counter = 0
        self.step_counter = 0
        self.model = mujoco.MjModel.from_xml_string(xml)
        self.data = mujoco.MjData(self.model)
        self.renderer = mujoco.Renderer(self.model)
        self.csv = open("./log/data.csv", "w",newline='')
        self.writer = csv.writer(self.csv)
        self.writer.writerow(["episode","step","reward"])

        # enable joint visualization option:
        self.scene_option = mujoco.MjvOption()
        self.scene_option.flags[mujoco.mjtVisFlag.mjVIS_JOINT] = True
        
        self.action_space = spaces.Box(low=-1, high=1, 
                                       shape=(21,), dtype=np.float32)

        self.observation_space = spaces.Box(low=-100, high=100,
                                            shape=(60,), dtype=np.float32)

    def step(self, action):
        #apply action to the environment
        self.step_counter = self.step_counter + 1
        self.data.ctrl=action
        mujoco.mj_step(self.model, self.data)
        observation = np.array([])
        observation = np.append(observation,[self.data.geom(id).xpos for id in range(self.model.ngeom)])
        observation = np.array(observation,dtype=np.float32)
        reward =  - abs(np.sum(action))
        #if len(self.data.contact.pos) != 0:
        reward = reward - abs(np.sum(self.data.sensor("velocity").data))*8
        done = False
        if self.data.time > 4:
            done = True
        info = {}
        self.writer.writerow([self.counter,self.step_counter,reward])
        return observation, reward, done, info

    def reset(self):
        #randomizing the initial condition by random control input
        mujoco.mj_resetDataKeyframe(self.model, self.data,0)
        self.model.opt.gravity = (0, 0, 1)
        for i in range(20):
            self.data.ctrl=self.action_space.sample()
            mujoco.mj_step(self.model, self.data)
        self.model.opt.gravity = (0, 0, -9.81) 
        
        
        observation = np.array([])
        observation = np.append(observation,[self.data.geom(id).xpos for id in range(self.model.ngeom)])
        observation = np.array(observation,dtype=np.float32)
        self.counter=self.counter + 1 
        self.step_counter = 0
        print(self.counter)
        return observation  # reward, done, info can't be included

    def render(self, mode="human"):
        duration = 4  # (seconds)
        framerate = 60  # (Hz)
        print("ren")
        frames = []
        self.reset()
        while self.data.time < duration:
            self.step(spaces.Box(low=-1, high=1,shape=(21,), dtype=np.float32).sample())
            if len(frames) < self.data.time * framerate:
                self.renderer.update_scene(self.data, scene_option=self.scene_option)
                pixels = self.renderer.render().copy()
                frames.append(pixels)
        # Simulate and display video.
        media.show_video(frames, fps=framerate)
        media.write_video('./log/v.mp4', frames, fps=framerate)
        ...
    def close(self):
        self.csv.close()

# %%
n_actions = humanoidEnv(humanoid_xml).action_space.shape
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
logger = configure("./log/", ["stdout", "csv","json"])

model = DDPG("MlpPolicy", humanoidEnv(humanoid_xml), action_noise=action_noise, verbose=2)
model.set_logger(logger)
model.learn(total_timesteps=781*1000,log_interval=1)
# Out:
# Logging to ./log/
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 1
# 2
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -4.29e+03 |
# | time/              |           |
# |    episodes        | 1         |
# |    fps             | 526       |
# |    time_elapsed    | 1         |
# |    total_timesteps | 781       |
# ----------------------------------
# 3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -5.3e+03 |
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 103      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1562     |
# | train/             |          |
# |    actor_loss      | 1.83     |
# |    critic_loss     | 17.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 781      |
# ---------------------------------
# 4
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.91e+03 |
# | time/              |           |
# |    episodes        | 3         |
# |    fps             | 78        |
# |    time_elapsed    | 29        |
# |    total_timesteps | 2343      |
# | train/             |           |
# |    actor_loss      | 4.04      |
# |    critic_loss     | 8.57      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1562      |
# ----------------------------------
# 5
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.29e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 71        |
# |    time_elapsed    | 43        |
# |    total_timesteps | 3124      |
# | train/             |           |
# |    actor_loss      | 5.9       |
# |    critic_loss     | 11.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2343      |
# ----------------------------------
# 6
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.31e+03 |
# | time/              |           |
# |    episodes        | 5         |
# |    fps             | 63        |
# |    time_elapsed    | 61        |
# |    total_timesteps | 3905      |
# | train/             |           |
# |    actor_loss      | -11.1     |
# |    critic_loss     | 10.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3124      |
# ----------------------------------
# 7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -8.3e+03 |
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 59       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 4686     |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 13       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3905     |
# ---------------------------------
# 8
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.59e+03 |
# | time/              |           |
# |    episodes        | 7         |
# |    fps             | 57        |
# |    time_elapsed    | 95        |
# |    total_timesteps | 5467      |
# | train/             |           |
# |    actor_loss      | -38.2     |
# |    critic_loss     | 18.1      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4686      |
# ----------------------------------
# 9
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.55e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 56        |
# |    time_elapsed    | 110       |
# |    total_timesteps | 6248      |
# | train/             |           |
# |    actor_loss      | -52.1     |
# |    critic_loss     | 20        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5467      |
# ----------------------------------
# 10
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.74e+03 |
# | time/              |           |
# |    episodes        | 9         |
# |    fps             | 55        |
# |    time_elapsed    | 126       |
# |    total_timesteps | 7029      |
# | train/             |           |
# |    actor_loss      | -62.5     |
# |    critic_loss     | 28.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6248      |
# ----------------------------------
# 11
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.41e+03 |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 55        |
# |    time_elapsed    | 141       |
# |    total_timesteps | 7810      |
# | train/             |           |
# |    actor_loss      | -78.1     |
# |    critic_loss     | 36.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7029      |
# ----------------------------------
# 12
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -8.08e+03 |
# | time/              |           |
# |    episodes        | 11        |
# |    fps             | 54        |
# |    time_elapsed    | 157       |
# |    total_timesteps | 8591      |
# | train/             |           |
# |    actor_loss      | -95.8     |
# |    critic_loss     | 50.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7810      |
# ----------------------------------
# 13
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.83e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 54        |
# |    time_elapsed    | 173       |
# |    total_timesteps | 9372      |
# | train/             |           |
# |    actor_loss      | -129      |
# |    critic_loss     | 80.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8591      |
# ----------------------------------
# 14
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.78e+03 |
# | time/              |           |
# |    episodes        | 13        |
# |    fps             | 53        |
# |    time_elapsed    | 188       |
# |    total_timesteps | 10153     |
# | train/             |           |
# |    actor_loss      | -172      |
# |    critic_loss     | 143       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9372      |
# ----------------------------------
# 15
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.74e+03 |
# | time/              |           |
# |    episodes        | 14        |
# |    fps             | 53        |
# |    time_elapsed    | 204       |
# |    total_timesteps | 10934     |
# | train/             |           |
# |    actor_loss      | -219      |
# |    critic_loss     | 194       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10153     |
# ----------------------------------
# 16
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.64e+03 |
# | time/              |           |
# |    episodes        | 15        |
# |    fps             | 53        |
# |    time_elapsed    | 219       |
# |    total_timesteps | 11715     |
# | train/             |           |
# |    actor_loss      | -286      |
# |    critic_loss     | 315       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10934     |
# ----------------------------------
# 17
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.85e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 53        |
# |    time_elapsed    | 235       |
# |    total_timesteps | 12496     |
# | train/             |           |
# |    actor_loss      | -361      |
# |    critic_loss     | 655       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11715     |
# ----------------------------------
# 18
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -7.7e+03 |
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 52       |
# |    time_elapsed    | 251      |
# |    total_timesteps | 13277    |
# | train/             |          |
# |    actor_loss      | -472     |
# |    critic_loss     | 1.16e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12496    |
# ---------------------------------
# 19
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.57e+03 |
# | time/              |           |
# |    episodes        | 18        |
# |    fps             | 52        |
# |    time_elapsed    | 267       |
# |    total_timesteps | 14058     |
# | train/             |           |
# |    actor_loss      | -594      |
# |    critic_loss     | 1.2e+03   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13277     |
# ----------------------------------
# 20
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.46e+03 |
# | time/              |           |
# |    episodes        | 19        |
# |    fps             | 52        |
# |    time_elapsed    | 283       |
# |    total_timesteps | 14839     |
# | train/             |           |
# |    actor_loss      | -719      |
# |    critic_loss     | 2.02e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14058     |
# ----------------------------------
# 21
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.36e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 52        |
# |    time_elapsed    | 298       |
# |    total_timesteps | 15620     |
# | train/             |           |
# |    actor_loss      | -848      |
# |    critic_loss     | 2.6e+03   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14839     |
# ----------------------------------
# 22
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.34e+03 |
# | time/              |           |
# |    episodes        | 21        |
# |    fps             | 52        |
# |    time_elapsed    | 314       |
# |    total_timesteps | 16401     |
# | train/             |           |
# |    actor_loss      | -995      |
# |    critic_loss     | 4.72e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15620     |
# ----------------------------------
# 23
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.39e+03 |
# | time/              |           |
# |    episodes        | 22        |
# |    fps             | 52        |
# |    time_elapsed    | 330       |
# |    total_timesteps | 17182     |
# | train/             |           |
# |    actor_loss      | -1.24e+03 |
# |    critic_loss     | 3.98e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16401     |
# ----------------------------------
# 24
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.33e+03 |
# | time/              |           |
# |    episodes        | 23        |
# |    fps             | 51        |
# |    time_elapsed    | 345       |
# |    total_timesteps | 17963     |
# | train/             |           |
# |    actor_loss      | -1.44e+03 |
# |    critic_loss     | 5.89e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17182     |
# ----------------------------------
# 25
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.33e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 51        |
# |    time_elapsed    | 361       |
# |    total_timesteps | 18744     |
# | train/             |           |
# |    actor_loss      | -1.64e+03 |
# |    critic_loss     | 5.63e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17963     |
# ----------------------------------
# 26
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.3e+03  |
# | time/              |           |
# |    episodes        | 25        |
# |    fps             | 51        |
# |    time_elapsed    | 380       |
# |    total_timesteps | 19525     |
# | train/             |           |
# |    actor_loss      | -1.93e+03 |
# |    critic_loss     | 1.29e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18744     |
# ----------------------------------
# 27
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.28e+03 |
# | time/              |           |
# |    episodes        | 26        |
# |    fps             | 50        |
# |    time_elapsed    | 399       |
# |    total_timesteps | 20306     |
# | train/             |           |
# |    actor_loss      | -2.09e+03 |
# |    critic_loss     | 1.66e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19525     |
# ----------------------------------
# 28
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.31e+03 |
# | time/              |           |
# |    episodes        | 27        |
# |    fps             | 50        |
# |    time_elapsed    | 415       |
# |    total_timesteps | 21087     |
# | train/             |           |
# |    actor_loss      | -2.27e+03 |
# |    critic_loss     | 1.73e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20306     |
# ----------------------------------
# 29
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.27e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 50        |
# |    time_elapsed    | 430       |
# |    total_timesteps | 21868     |
# | train/             |           |
# |    actor_loss      | -2.47e+03 |
# |    critic_loss     | 2.07e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21087     |
# ----------------------------------
# 30
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.2e+03  |
# | time/              |           |
# |    episodes        | 29        |
# |    fps             | 50        |
# |    time_elapsed    | 448       |
# |    total_timesteps | 22649     |
# | train/             |           |
# |    actor_loss      | -2.65e+03 |
# |    critic_loss     | 1.97e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21868     |
# ----------------------------------
# 31
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.16e+03 |
# | time/              |           |
# |    episodes        | 30        |
# |    fps             | 50        |
# |    time_elapsed    | 464       |
# |    total_timesteps | 23430     |
# | train/             |           |
# |    actor_loss      | -2.85e+03 |
# |    critic_loss     | 2.13e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22649     |
# ----------------------------------
# 32
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.16e+03 |
# | time/              |           |
# |    episodes        | 31        |
# |    fps             | 50        |
# |    time_elapsed    | 479       |
# |    total_timesteps | 24211     |
# | train/             |           |
# |    actor_loss      | -3.19e+03 |
# |    critic_loss     | 2.76e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23430     |
# ----------------------------------
# 33
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.23e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 50        |
# |    time_elapsed    | 495       |
# |    total_timesteps | 24992     |
# | train/             |           |
# |    actor_loss      | -3.38e+03 |
# |    critic_loss     | 3.14e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24211     |
# ----------------------------------
# 34
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.29e+03 |
# | time/              |           |
# |    episodes        | 33        |
# |    fps             | 50        |
# |    time_elapsed    | 513       |
# |    total_timesteps | 25773     |
# | train/             |           |
# |    actor_loss      | -3.6e+03  |
# |    critic_loss     | 3.86e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24992     |
# ----------------------------------
# 35
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.23e+03 |
# | time/              |           |
# |    episodes        | 34        |
# |    fps             | 50        |
# |    time_elapsed    | 529       |
# |    total_timesteps | 26554     |
# | train/             |           |
# |    actor_loss      | -4.09e+03 |
# |    critic_loss     | 3.87e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25773     |
# ----------------------------------
# 36
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.13e+03 |
# | time/              |           |
# |    episodes        | 35        |
# |    fps             | 50        |
# |    time_elapsed    | 545       |
# |    total_timesteps | 27335     |
# | train/             |           |
# |    actor_loss      | -4.5e+03  |
# |    critic_loss     | 5.03e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26554     |
# ----------------------------------
# 37
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.12e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 50        |
# |    time_elapsed    | 561       |
# |    total_timesteps | 28116     |
# | train/             |           |
# |    actor_loss      | -4.8e+03  |
# |    critic_loss     | 7.78e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27335     |
# ----------------------------------
# 38
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.19e+03 |
# | time/              |           |
# |    episodes        | 37        |
# |    fps             | 50        |
# |    time_elapsed    | 577       |
# |    total_timesteps | 28897     |
# | train/             |           |
# |    actor_loss      | -5.12e+03 |
# |    critic_loss     | 5.06e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28116     |
# ----------------------------------
# 39
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.15e+03 |
# | time/              |           |
# |    episodes        | 38        |
# |    fps             | 50        |
# |    time_elapsed    | 593       |
# |    total_timesteps | 29678     |
# | train/             |           |
# |    actor_loss      | -5.56e+03 |
# |    critic_loss     | 6.01e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28897     |
# ----------------------------------
# 40
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.21e+03 |
# | time/              |           |
# |    episodes        | 39        |
# |    fps             | 49        |
# |    time_elapsed    | 609       |
# |    total_timesteps | 30459     |
# | train/             |           |
# |    actor_loss      | -6.06e+03 |
# |    critic_loss     | 8.66e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29678     |
# ----------------------------------
# 41
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.21e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 49        |
# |    time_elapsed    | 626       |
# |    total_timesteps | 31240     |
# | train/             |           |
# |    actor_loss      | -6.5e+03  |
# |    critic_loss     | 7.9e+04   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30459     |
# ----------------------------------
# 42
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.24e+03 |
# | time/              |           |
# |    episodes        | 41        |
# |    fps             | 49        |
# |    time_elapsed    | 642       |
# |    total_timesteps | 32021     |
# | train/             |           |
# |    actor_loss      | -7.09e+03 |
# |    critic_loss     | 9.41e+04  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31240     |
# ----------------------------------
# 43
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.25e+03 |
# | time/              |           |
# |    episodes        | 42        |
# |    fps             | 49        |
# |    time_elapsed    | 658       |
# |    total_timesteps | 32802     |
# | train/             |           |
# |    actor_loss      | -7.77e+03 |
# |    critic_loss     | 1.45e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32021     |
# ----------------------------------
# 44
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.18e+03 |
# | time/              |           |
# |    episodes        | 43        |
# |    fps             | 49        |
# |    time_elapsed    | 674       |
# |    total_timesteps | 33583     |
# | train/             |           |
# |    actor_loss      | -8.55e+03 |
# |    critic_loss     | 1.63e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32802     |
# ----------------------------------
# 45
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.13e+03 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 49        |
# |    time_elapsed    | 691       |
# |    total_timesteps | 34364     |
# | train/             |           |
# |    actor_loss      | -9.36e+03 |
# |    critic_loss     | 1.91e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33583     |
# ----------------------------------
# 46
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.09e+03 |
# | time/              |           |
# |    episodes        | 45        |
# |    fps             | 49        |
# |    time_elapsed    | 707       |
# |    total_timesteps | 35145     |
# | train/             |           |
# |    actor_loss      | -1.02e+04 |
# |    critic_loss     | 1.81e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34364     |
# ----------------------------------
# 47
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.13e+03 |
# | time/              |           |
# |    episodes        | 46        |
# |    fps             | 49        |
# |    time_elapsed    | 723       |
# |    total_timesteps | 35926     |
# | train/             |           |
# |    actor_loss      | -1.1e+04  |
# |    critic_loss     | 2.27e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35145     |
# ----------------------------------
# 48
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.11e+03 |
# | time/              |           |
# |    episodes        | 47        |
# |    fps             | 49        |
# |    time_elapsed    | 739       |
# |    total_timesteps | 36707     |
# | train/             |           |
# |    actor_loss      | -1.17e+04 |
# |    critic_loss     | 2.93e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35926     |
# ----------------------------------
# 49
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.05e+03 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 49        |
# |    time_elapsed    | 756       |
# |    total_timesteps | 37488     |
# | train/             |           |
# |    actor_loss      | -1.25e+04 |
# |    critic_loss     | 2.97e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36707     |
# ----------------------------------
# 50
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.05e+03 |
# | time/              |           |
# |    episodes        | 49        |
# |    fps             | 49        |
# |    time_elapsed    | 772       |
# |    total_timesteps | 38269     |
# | train/             |           |
# |    actor_loss      | -1.34e+04 |
# |    critic_loss     | 3.13e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37488     |
# ----------------------------------
# 51
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.11e+03 |
# | time/              |           |
# |    episodes        | 50        |
# |    fps             | 49        |
# |    time_elapsed    | 788       |
# |    total_timesteps | 39050     |
# | train/             |           |
# |    actor_loss      | -1.42e+04 |
# |    critic_loss     | 3.73e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38269     |
# ----------------------------------
# 52
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.08e+03 |
# | time/              |           |
# |    episodes        | 51        |
# |    fps             | 49        |
# |    time_elapsed    | 805       |
# |    total_timesteps | 39831     |
# | train/             |           |
# |    actor_loss      | -1.51e+04 |
# |    critic_loss     | 4.4e+05   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39050     |
# ----------------------------------
# 53
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.07e+03 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 49        |
# |    time_elapsed    | 822       |
# |    total_timesteps | 40612     |
# | train/             |           |
# |    actor_loss      | -1.61e+04 |
# |    critic_loss     | 4.06e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39831     |
# ----------------------------------
# 54
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.03e+03 |
# | time/              |           |
# |    episodes        | 53        |
# |    fps             | 49        |
# |    time_elapsed    | 838       |
# |    total_timesteps | 41393     |
# | train/             |           |
# |    actor_loss      | -1.71e+04 |
# |    critic_loss     | 5.19e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40612     |
# ----------------------------------
# 55
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.03e+03 |
# | time/              |           |
# |    episodes        | 54        |
# |    fps             | 49        |
# |    time_elapsed    | 854       |
# |    total_timesteps | 42174     |
# | train/             |           |
# |    actor_loss      | -1.8e+04  |
# |    critic_loss     | 5.47e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41393     |
# ----------------------------------
# 56
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7e+03    |
# | time/              |           |
# |    episodes        | 55        |
# |    fps             | 49        |
# |    time_elapsed    | 872       |
# |    total_timesteps | 42955     |
# | train/             |           |
# |    actor_loss      | -1.89e+04 |
# |    critic_loss     | 6.08e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42174     |
# ----------------------------------
# 57
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.99e+03 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 49        |
# |    time_elapsed    | 888       |
# |    total_timesteps | 43736     |
# | train/             |           |
# |    actor_loss      | -1.98e+04 |
# |    critic_loss     | 7.12e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42955     |
# ----------------------------------
# 58
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.97e+03 |
# | time/              |           |
# |    episodes        | 57        |
# |    fps             | 49        |
# |    time_elapsed    | 904       |
# |    total_timesteps | 44517     |
# | train/             |           |
# |    actor_loss      | -2.08e+04 |
# |    critic_loss     | 7.09e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43736     |
# ----------------------------------
# 59
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.01e+03 |
# | time/              |           |
# |    episodes        | 58        |
# |    fps             | 49        |
# |    time_elapsed    | 920       |
# |    total_timesteps | 45298     |
# | train/             |           |
# |    actor_loss      | -2.18e+04 |
# |    critic_loss     | 7.45e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44517     |
# ----------------------------------
# 60
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.96e+03 |
# | time/              |           |
# |    episodes        | 59        |
# |    fps             | 49        |
# |    time_elapsed    | 935       |
# |    total_timesteps | 46079     |
# | train/             |           |
# |    actor_loss      | -2.29e+04 |
# |    critic_loss     | 7.64e+05  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45298     |
# ----------------------------------
# 61
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.92e+03 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 49        |
# |    time_elapsed    | 951       |
# |    total_timesteps | 46860     |
# | train/             |           |
# |    actor_loss      | -2.38e+04 |
# |    critic_loss     | 9.6e+05   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46079     |
# ----------------------------------
# 62
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.96e+03 |
# | time/              |           |
# |    episodes        | 61        |
# |    fps             | 49        |
# |    time_elapsed    | 968       |
# |    total_timesteps | 47641     |
# | train/             |           |
# |    actor_loss      | -2.48e+04 |
# |    critic_loss     | 1e+06     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46860     |
# ----------------------------------
# 63
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.95e+03 |
# | time/              |           |
# |    episodes        | 62        |
# |    fps             | 49        |
# |    time_elapsed    | 984       |
# |    total_timesteps | 48422     |
# | train/             |           |
# |    actor_loss      | -2.6e+04  |
# |    critic_loss     | 1.08e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47641     |
# ----------------------------------
# 64
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.96e+03 |
# | time/              |           |
# |    episodes        | 63        |
# |    fps             | 49        |
# |    time_elapsed    | 1003      |
# |    total_timesteps | 49203     |
# | train/             |           |
# |    actor_loss      | -2.7e+04  |
# |    critic_loss     | 1.19e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48422     |
# ----------------------------------
# 65
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.93e+03 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 49        |
# |    time_elapsed    | 1018      |
# |    total_timesteps | 49984     |
# | train/             |           |
# |    actor_loss      | -2.8e+04  |
# |    critic_loss     | 1.28e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49203     |
# ----------------------------------
# 66
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.91e+03 |
# | time/              |           |
# |    episodes        | 65        |
# |    fps             | 49        |
# |    time_elapsed    | 1034      |
# |    total_timesteps | 50765     |
# | train/             |           |
# |    actor_loss      | -2.9e+04  |
# |    critic_loss     | 1.15e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49984     |
# ----------------------------------
# 67
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.92e+03 |
# | time/              |           |
# |    episodes        | 66        |
# |    fps             | 49        |
# |    time_elapsed    | 1050      |
# |    total_timesteps | 51546     |
# | train/             |           |
# |    actor_loss      | -2.99e+04 |
# |    critic_loss     | 1.17e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50765     |
# ----------------------------------
# 68
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.88e+03 |
# | time/              |           |
# |    episodes        | 67        |
# |    fps             | 49        |
# |    time_elapsed    | 1066      |
# |    total_timesteps | 52327     |
# | train/             |           |
# |    actor_loss      | -3.07e+04 |
# |    critic_loss     | 1.33e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 51546     |
# ----------------------------------
# 69
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.86e+03 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 49        |
# |    time_elapsed    | 1082      |
# |    total_timesteps | 53108     |
# | train/             |           |
# |    actor_loss      | -3.16e+04 |
# |    critic_loss     | 1.29e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52327     |
# ----------------------------------
# 70
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.91e+03 |
# | time/              |           |
# |    episodes        | 69        |
# |    fps             | 49        |
# |    time_elapsed    | 1097      |
# |    total_timesteps | 53889     |
# | train/             |           |
# |    actor_loss      | -3.24e+04 |
# |    critic_loss     | 1.21e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 53108     |
# ----------------------------------
# 71
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.91e+03 |
# | time/              |           |
# |    episodes        | 70        |
# |    fps             | 49        |
# |    time_elapsed    | 1115      |
# |    total_timesteps | 54670     |
# | train/             |           |
# |    actor_loss      | -3.35e+04 |
# |    critic_loss     | 1.23e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 53889     |
# ----------------------------------
# 72
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.94e+03 |
# | time/              |           |
# |    episodes        | 71        |
# |    fps             | 48        |
# |    time_elapsed    | 1131      |
# |    total_timesteps | 55451     |
# | train/             |           |
# |    actor_loss      | -3.42e+04 |
# |    critic_loss     | 1.87e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 54670     |
# ----------------------------------
# 73
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.94e+03 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 48        |
# |    time_elapsed    | 1148      |
# |    total_timesteps | 56232     |
# | train/             |           |
# |    actor_loss      | -3.51e+04 |
# |    critic_loss     | 1.86e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 55451     |
# ----------------------------------
# 74
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.94e+03 |
# | time/              |           |
# |    episodes        | 73        |
# |    fps             | 48        |
# |    time_elapsed    | 1165      |
# |    total_timesteps | 57013     |
# | train/             |           |
# |    actor_loss      | -3.62e+04 |
# |    critic_loss     | 1.45e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 56232     |
# ----------------------------------
# 75
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.98e+03 |
# | time/              |           |
# |    episodes        | 74        |
# |    fps             | 48        |
# |    time_elapsed    | 1182      |
# |    total_timesteps | 57794     |
# | train/             |           |
# |    actor_loss      | -3.72e+04 |
# |    critic_loss     | 1.49e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 57013     |
# ----------------------------------
# 76
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.96e+03 |
# | time/              |           |
# |    episodes        | 75        |
# |    fps             | 48        |
# |    time_elapsed    | 1198      |
# |    total_timesteps | 58575     |
# | train/             |           |
# |    actor_loss      | -3.82e+04 |
# |    critic_loss     | 2.1e+06   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 57794     |
# ----------------------------------
# 77
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.97e+03 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 48        |
# |    time_elapsed    | 1214      |
# |    total_timesteps | 59356     |
# | train/             |           |
# |    actor_loss      | -3.9e+04  |
# |    critic_loss     | 2.27e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 58575     |
# ----------------------------------
# 78
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.99e+03 |
# | time/              |           |
# |    episodes        | 77        |
# |    fps             | 48        |
# |    time_elapsed    | 1230      |
# |    total_timesteps | 60137     |
# | train/             |           |
# |    actor_loss      | -3.98e+04 |
# |    critic_loss     | 1.87e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 59356     |
# ----------------------------------
# 79
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -6.98e+03 |
# | time/              |           |
# |    episodes        | 78        |
# |    fps             | 48        |
# |    time_elapsed    | 1247      |
# |    total_timesteps | 60918     |
# | train/             |           |
# |    actor_loss      | -4.06e+04 |
# |    critic_loss     | 2.38e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 60137     |
# ----------------------------------
# 80
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7e+03    |
# | time/              |           |
# |    episodes        | 79        |
# |    fps             | 48        |
# |    time_elapsed    | 1263      |
# |    total_timesteps | 61699     |
# | train/             |           |
# |    actor_loss      | -4.16e+04 |
# |    critic_loss     | 2.28e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 60918     |
# ----------------------------------
# 81
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7e+03    |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 48        |
# |    time_elapsed    | 1280      |
# |    total_timesteps | 62480     |
# | train/             |           |
# |    actor_loss      | -4.25e+04 |
# |    critic_loss     | 2.42e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 61699     |
# ----------------------------------
# 82
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.03e+03 |
# | time/              |           |
# |    episodes        | 81        |
# |    fps             | 48        |
# |    time_elapsed    | 1297      |
# |    total_timesteps | 63261     |
# | train/             |           |
# |    actor_loss      | -4.33e+04 |
# |    critic_loss     | 3.02e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 62480     |
# ----------------------------------
# 83
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.03e+03 |
# | time/              |           |
# |    episodes        | 82        |
# |    fps             | 48        |
# |    time_elapsed    | 1314      |
# |    total_timesteps | 64042     |
# | train/             |           |
# |    actor_loss      | -4.42e+04 |
# |    critic_loss     | 2.48e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 63261     |
# ----------------------------------
# 84
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.04e+03 |
# | time/              |           |
# |    episodes        | 83        |
# |    fps             | 48        |
# |    time_elapsed    | 1331      |
# |    total_timesteps | 64823     |
# | train/             |           |
# |    actor_loss      | -4.54e+04 |
# |    critic_loss     | 2.98e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 64042     |
# ----------------------------------
# 85
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.08e+03 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 48        |
# |    time_elapsed    | 1348      |
# |    total_timesteps | 65604     |
# | train/             |           |
# |    actor_loss      | -4.63e+04 |
# |    critic_loss     | 3.09e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 64823     |
# ----------------------------------
# 86
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.1e+03  |
# | time/              |           |
# |    episodes        | 85        |
# |    fps             | 48        |
# |    time_elapsed    | 1366      |
# |    total_timesteps | 66385     |
# | train/             |           |
# |    actor_loss      | -4.73e+04 |
# |    critic_loss     | 3e+06     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 65604     |
# ----------------------------------
# 87
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.08e+03 |
# | time/              |           |
# |    episodes        | 86        |
# |    fps             | 48        |
# |    time_elapsed    | 1383      |
# |    total_timesteps | 67166     |
# | train/             |           |
# |    actor_loss      | -4.83e+04 |
# |    critic_loss     | 3.34e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 66385     |
# ----------------------------------
# 88
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.05e+03 |
# | time/              |           |
# |    episodes        | 87        |
# |    fps             | 48        |
# |    time_elapsed    | 1401      |
# |    total_timesteps | 67947     |
# | train/             |           |
# |    actor_loss      | -4.93e+04 |
# |    critic_loss     | 3.43e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 67166     |
# ----------------------------------
# 89
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.07e+03 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 48        |
# |    time_elapsed    | 1418      |
# |    total_timesteps | 68728     |
# | train/             |           |
# |    actor_loss      | -5.05e+04 |
# |    critic_loss     | 3.17e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 67947     |
# ----------------------------------
# 90
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.03e+03 |
# | time/              |           |
# |    episodes        | 89        |
# |    fps             | 48        |
# |    time_elapsed    | 1436      |
# |    total_timesteps | 69509     |
# | train/             |           |
# |    actor_loss      | -5.18e+04 |
# |    critic_loss     | 4.58e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 68728     |
# ----------------------------------
# 91
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.05e+03 |
# | time/              |           |
# |    episodes        | 90        |
# |    fps             | 48        |
# |    time_elapsed    | 1454      |
# |    total_timesteps | 70290     |
# | train/             |           |
# |    actor_loss      | -5.33e+04 |
# |    critic_loss     | 4.45e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 69509     |
# ----------------------------------
# 92
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -7.12e+03 |
# | time/              |           |
# |    episodes        | 91        |
# |    fps             | 48        |
# |    time_elapsed    | 1472      |
# |    total_timesteps | 71071     |
# | train/             |           |
# |    actor_loss      | -5.5e+04  |
# |    critic_loss     | 3.62e+06  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 70290     |
# ----------------------------------
# 93
# ----------------------------------
# ...
# |    critic_loss     | 310       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 756789    |
# ----------------------------------
# 972
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.74e+03 |
# | time/              |           |
# |    episodes        | 971       |
# |    fps             | 38        |
# |    time_elapsed    | 19487     |
# |    total_timesteps | 758351    |
# | train/             |           |
# |    actor_loss      | -76.5     |
# |    critic_loss     | 358       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 757570    |
# ----------------------------------
# 973
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.73e+03 |
# | time/              |           |
# |    episodes        | 972       |
# |    fps             | 38        |
# |    time_elapsed    | 19509     |
# |    total_timesteps | 759132    |
# | train/             |           |
# |    actor_loss      | -70.1     |
# |    critic_loss     | 350       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 758351    |
# ----------------------------------
# 974
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.72e+03 |
# | time/              |           |
# |    episodes        | 973       |
# |    fps             | 38        |
# |    time_elapsed    | 19531     |
# |    total_timesteps | 759913    |
# | train/             |           |
# |    actor_loss      | -62.4     |
# |    critic_loss     | 357       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 759132    |
# ----------------------------------
# 975
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.71e+03 |
# | time/              |           |
# |    episodes        | 974       |
# |    fps             | 38        |
# |    time_elapsed    | 19552     |
# |    total_timesteps | 760694    |
# | train/             |           |
# |    actor_loss      | -60.7     |
# |    critic_loss     | 342       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 759913    |
# ----------------------------------
# 976
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.71e+03 |
# | time/              |           |
# |    episodes        | 975       |
# |    fps             | 38        |
# |    time_elapsed    | 19573     |
# |    total_timesteps | 761475    |
# | train/             |           |
# |    actor_loss      | -56.6     |
# |    critic_loss     | 338       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 760694    |
# ----------------------------------
# 977
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.73e+03 |
# | time/              |           |
# |    episodes        | 976       |
# |    fps             | 38        |
# |    time_elapsed    | 19595     |
# |    total_timesteps | 762256    |
# | train/             |           |
# |    actor_loss      | -51       |
# |    critic_loss     | 318       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 761475    |
# ----------------------------------
# 978
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.69e+03 |
# | time/              |           |
# |    episodes        | 977       |
# |    fps             | 38        |
# |    time_elapsed    | 19616     |
# |    total_timesteps | 763037    |
# | train/             |           |
# |    actor_loss      | -45.5     |
# |    critic_loss     | 292       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 762256    |
# ----------------------------------
# 979
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.69e+03 |
# | time/              |           |
# |    episodes        | 978       |
# |    fps             | 38        |
# |    time_elapsed    | 19637     |
# |    total_timesteps | 763818    |
# | train/             |           |
# |    actor_loss      | -46.8     |
# |    critic_loss     | 307       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 763037    |
# ----------------------------------
# 980
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.71e+03 |
# | time/              |           |
# |    episodes        | 979       |
# |    fps             | 38        |
# |    time_elapsed    | 19658     |
# |    total_timesteps | 764599    |
# | train/             |           |
# |    actor_loss      | -40.9     |
# |    critic_loss     | 425       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 763818    |
# ----------------------------------
# 981
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.69e+03 |
# | time/              |           |
# |    episodes        | 980       |
# |    fps             | 38        |
# |    time_elapsed    | 19679     |
# |    total_timesteps | 765380    |
# | train/             |           |
# |    actor_loss      | -37.1     |
# |    critic_loss     | 393       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 764599    |
# ----------------------------------
# 982
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.67e+03 |
# | time/              |           |
# |    episodes        | 981       |
# |    fps             | 38        |
# |    time_elapsed    | 19703     |
# |    total_timesteps | 766161    |
# | train/             |           |
# |    actor_loss      | -35.1     |
# |    critic_loss     | 274       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 765380    |
# ----------------------------------
# 983
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.65e+03 |
# | time/              |           |
# |    episodes        | 982       |
# |    fps             | 38        |
# |    time_elapsed    | 19726     |
# |    total_timesteps | 766942    |
# | train/             |           |
# |    actor_loss      | -32       |
# |    critic_loss     | 352       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 766161    |
# ----------------------------------
# 984
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.63e+03 |
# | time/              |           |
# |    episodes        | 983       |
# |    fps             | 38        |
# |    time_elapsed    | 19748     |
# |    total_timesteps | 767723    |
# | train/             |           |
# |    actor_loss      | -30.2     |
# |    critic_loss     | 439       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 766942    |
# ----------------------------------
# 985
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.64e+03 |
# | time/              |           |
# |    episodes        | 984       |
# |    fps             | 38        |
# |    time_elapsed    | 19769     |
# |    total_timesteps | 768504    |
# | train/             |           |
# |    actor_loss      | -29       |
# |    critic_loss     | 312       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 767723    |
# ----------------------------------
# 986
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.64e+03 |
# | time/              |           |
# |    episodes        | 985       |
# |    fps             | 38        |
# |    time_elapsed    | 19791     |
# |    total_timesteps | 769285    |
# | train/             |           |
# |    actor_loss      | -27.9     |
# |    critic_loss     | 260       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 768504    |
# ----------------------------------
# 987
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.67e+03 |
# | time/              |           |
# |    episodes        | 986       |
# |    fps             | 38        |
# |    time_elapsed    | 19812     |
# |    total_timesteps | 770066    |
# | train/             |           |
# |    actor_loss      | -27.4     |
# |    critic_loss     | 292       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 769285    |
# ----------------------------------
# 988
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.65e+03 |
# | time/              |           |
# |    episodes        | 987       |
# |    fps             | 38        |
# |    time_elapsed    | 19834     |
# |    total_timesteps | 770847    |
# | train/             |           |
# |    actor_loss      | -23.3     |
# |    critic_loss     | 284       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 770066    |
# ----------------------------------
# 989
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.65e+03 |
# | time/              |           |
# |    episodes        | 988       |
# |    fps             | 38        |
# |    time_elapsed    | 19855     |
# |    total_timesteps | 771628    |
# | train/             |           |
# |    actor_loss      | -24.2     |
# |    critic_loss     | 330       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 770847    |
# ----------------------------------
# 990
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.67e+03 |
# | time/              |           |
# |    episodes        | 989       |
# |    fps             | 38        |
# |    time_elapsed    | 19877     |
# |    total_timesteps | 772409    |
# | train/             |           |
# |    actor_loss      | -25.6     |
# |    critic_loss     | 262       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 771628    |
# ----------------------------------
# 991
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.64e+03 |
# | time/              |           |
# |    episodes        | 990       |
# |    fps             | 38        |
# |    time_elapsed    | 19899     |
# |    total_timesteps | 773190    |
# | train/             |           |
# |    actor_loss      | -23.4     |
# |    critic_loss     | 310       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 772409    |
# ----------------------------------
# 992
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.64e+03 |
# | time/              |           |
# |    episodes        | 991       |
# |    fps             | 38        |
# |    time_elapsed    | 19920     |
# |    total_timesteps | 773971    |
# | train/             |           |
# |    actor_loss      | -25.9     |
# |    critic_loss     | 331       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 773190    |
# ----------------------------------
# 993
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.64e+03 |
# | time/              |           |
# |    episodes        | 992       |
# |    fps             | 38        |
# |    time_elapsed    | 19942     |
# |    total_timesteps | 774752    |
# | train/             |           |
# |    actor_loss      | -24.4     |
# |    critic_loss     | 277       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 773971    |
# ----------------------------------
# 994
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.64e+03 |
# | time/              |           |
# |    episodes        | 993       |
# |    fps             | 38        |
# |    time_elapsed    | 19963     |
# |    total_timesteps | 775533    |
# | train/             |           |
# |    actor_loss      | -25.5     |
# |    critic_loss     | 249       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 774752    |
# ----------------------------------
# 995
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.63e+03 |
# | time/              |           |
# |    episodes        | 994       |
# |    fps             | 38        |
# |    time_elapsed    | 19985     |
# |    total_timesteps | 776314    |
# | train/             |           |
# |    actor_loss      | -25.7     |
# |    critic_loss     | 331       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 775533    |
# ----------------------------------
# 996
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.64e+03 |
# | time/              |           |
# |    episodes        | 995       |
# |    fps             | 38        |
# |    time_elapsed    | 20006     |
# |    total_timesteps | 777095    |
# | train/             |           |
# |    actor_loss      | -25.5     |
# |    critic_loss     | 286       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 776314    |
# ----------------------------------
# 997
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.63e+03 |
# | time/              |           |
# |    episodes        | 996       |
# |    fps             | 38        |
# |    time_elapsed    | 20027     |
# |    total_timesteps | 777876    |
# | train/             |           |
# |    actor_loss      | -22.5     |
# |    critic_loss     | 270       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 777095    |
# ----------------------------------
# 998
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.61e+03 |
# | time/              |           |
# |    episodes        | 997       |
# |    fps             | 38        |
# |    time_elapsed    | 20049     |
# |    total_timesteps | 778657    |
# | train/             |           |
# |    actor_loss      | -24.3     |
# |    critic_loss     | 282       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 777876    |
# ----------------------------------
# 999
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.62e+03 |
# | time/              |           |
# |    episodes        | 998       |
# |    fps             | 38        |
# |    time_elapsed    | 20072     |
# |    total_timesteps | 779438    |
# | train/             |           |
# |    actor_loss      | -24.4     |
# |    critic_loss     | 264       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 778657    |
# ----------------------------------
# 1000
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 781       |
# |    ep_rew_mean     | -5.62e+03 |
# | time/              |           |
# |    episodes        | 999       |
# |    fps             | 38        |
# |    time_elapsed    | 20093     |
# |    total_timesteps | 780219    |
# | train/             |           |
# |    actor_loss      | -18.3     |
# |    critic_loss     | 307       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 779438    |
# ----------------------------------
# 1001
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -5.6e+03 |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 38       |
# |    time_elapsed    | 20114    |
# |    total_timesteps | 781000   |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 319      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 780219   |
# ---------------------------------

# %%
env = model.get_env()

obs = env.reset()

action, _states = model.predict(obs)
obs, rewards, dones, info = env.step(action)
env.render()
# Out:
# 1006
# ren
# 1007
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
model.save("ddpg_humanoid")
